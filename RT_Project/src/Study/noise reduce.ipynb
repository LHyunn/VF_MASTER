# %%
import cv2
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
image = cv2.imread("/home/dais01/HyundaiRB/Data/Raw_Data_tif/Raw_Data/202212/20221221/22F007-01-021/22F007-01-021-1st-1-(2)-46.tif", cv2.IMREAD_GRAYSCALE)

                   
image.shape
# Out:
# (1256, 1256)

# %%
print(image[0, :])
# Out:
# [101 101 100 ...  97  96  96]

# %%
plt.figure(figsize=(20, 20))
plt.imshow(image, cmap="gray")

# %%
cv2.imwrite("/home/dais01/HyundaiRB/Data/Raw_Data_png/22F007-01-021-1st-1-(2)-46.png", image, [cv2.IMWRITE_PNG_COMPRESSION, 0])
# Out:
# True
